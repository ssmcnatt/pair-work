# %% [markdown]
# ## Day 22 Lecture 1 Assignment
#
# In this assignment, we will do some EDA to uncover basic patterns in our datasets. We will be using both the FIFA ratings dataset and the Chicago traffic crash dataset.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
crash_data = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/traffic_crashes_chicago.csv')
soccer_data = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/fifa_ratings.csv')

# %%
soccer_data.head()
# Out:
#        ID               Name  Overall  Crossing  Finishing  HeadingAccuracy  \
# 0  158023           L. Messi       94        84         95               70
# 1   20801  Cristiano Ronaldo       94        84         94               89
# 2  190871          Neymar Jr       92        79         87               62
# 3  192985       K. De Bruyne       91        93         82               55
# 4  183277          E. Hazard       91        81         84               61
#
#    ShortPassing  Volleys  Dribbling  Curve  ...  LongShots  Aggression  \
# 0            90       86         97     93  ...         94          48
# 1            81       87         88     81  ...         93          63
# 2            84       84         96     88  ...         82          56
# 3            92       82         86     85  ...         91          76
# 4            89       80         95     83  ...         80          54
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 0             22           94      94         75         96       33
# 1             29           95      82         85         95       28
# 2             36           89      87         81         94       27
# 3             61           87      94         79         88       68
# 4             41           87      89         86         91       34
#
#    StandingTackle  SlidingTackle
# 0              28             26
# 1              31             23
# 2              24             33
# 3              58             51
# 4              27             22
#
# [5 rows x 32 columns]

# %%
crash_data.head()
# Out:
#       RD_NO       CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 0  JC334993   7/4/2019 22:33                  45            NO CONTROLS
# 1  JC370822  7/30/2019 10:22                  30            NO CONTROLS
# 2  JC387098  8/10/2019 17:00                  25            NO CONTROLS
# 3  JC395195  8/16/2019 16:53                  30            NO CONTROLS
# 4  JC396604  8/17/2019 16:04                  30            NO CONTROLS
#
#   DEVICE_CONDITION WEATHER_CONDITION      LIGHTING_CONDITION  \
# 0      NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 1      NO CONTROLS             CLEAR                DAYLIGHT
# 2      NO CONTROLS             CLEAR                DAYLIGHT
# 3      NO CONTROLS             CLEAR                DAYLIGHT
# 4      NO CONTROLS             CLEAR                DAYLIGHT
#
#        FIRST_CRASH_TYPE                  TRAFFICWAY_TYPE  LANE_CNT  ...  \
# 0              REAR END       DIVIDED - W/MEDIAN BARRIER       NaN  ...
# 1               TURNING  DIVIDED - W/MEDIAN (NOT RAISED)       NaN  ...
# 2  PARKED MOTOR VEHICLE                          ONE-WAY       NaN  ...
# 3  PARKED MOTOR VEHICLE                      NOT DIVIDED       NaN  ...
# 4  PARKED MOTOR VEHICLE                      PARKING LOT       NaN  ...
#
#   WORKERS_PRESENT_I NUM_UNITS       MOST_SEVERE_INJURY INJURIES_TOTAL  \
# 0               NaN       NaN                      NaN            NaN
# 1               NaN       NaN                      NaN            NaN
# 2               NaN       1.0                      NaN            NaN
# 3               NaN       1.0  NO INDICATION OF INJURY            0.0
# 4               NaN       1.0  NO INDICATION OF INJURY            0.0
#
#   INJURIES_FATAL INJURIES_INCAPACITATING INJURIES_NON_INCAPACITATING  \
# 0            NaN                     NaN                         NaN
# 1            NaN                     NaN                         NaN
# 2            NaN                     NaN                         NaN
# 3            0.0                     0.0                         0.0
# 4            0.0                     0.0                         0.0
#
#   INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION INJURIES_UNKNOWN
# 0                           NaN                    NaN              NaN
# 1                           NaN                    NaN              NaN
# 2                           NaN                    NaN              NaN
# 3                           0.0                    1.0              0.0
# 4                           0.0                    1.0              0.0
#
# [5 rows x 41 columns]

# %%
soccer_data.columns
# Out:
# Index(['ID', 'Name', 'Overall', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle'],
#       dtype='object')

# %% [markdown]
# We will start with the FIFA dataset, which consists entirely of numeric features (we will ignore the player ID and name). Create a histogram of each numeric column in the dataset. What do you notice about the distributions of scores? Are there any particular distributions that jump out?

# %%
# answer goes here
soccer_data.hist(bins=30, figsize=(15, 10))
plt.show()

# %% [markdown]
# Next, generate pairplots between the Overall rating and the other numeric features (i.e. Overall-Crossing, Overall-Finishing....Overall-SlidingTackle). Are the results what you would expect, visually speaking? What are the strongest correlations that jump out?
#
# This dataset has many columns, so it may help to split up the pairwise scatterplots across two or three visuals. In addition, the scatterplots will probably be too crowded to be informative if the full dataset is used, so using a sample of the rows is advisable as well.

# %%
# answer goes here
soccer_sample = soccer_data.sample(n=20)
cols = ['Crossing', 'Finishing', 'HeadingAccuracy',
        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle']
colors = ['red', 'blue', 'green', 'orange', 'black', 'purple', 'yellow', 'brown']


ax = soccer_sample.plot(kind="scatter", x=cols[0], y="Overall", color=colors[0], label=cols[0])
for i in range(1, 4):
    soccer_sample.plot(kind="scatter", x=cols[i], y="Overall", color=colors[i], label=cols[i], ax=ax)
ax.set_xlabel("Overall")
ax.set_ylabel(" ")
plt.plot()

ax = soccer_sample.plot(kind="scatter", x=cols[4], y="Overall", color=colors[0], label=cols[4])
for i in range(5, 8):
    soccer_sample.plot(kind="scatter", x=cols[i], y="Overall", color=colors[i-4], label=cols[i], ax=ax)
ax.set_xlabel("Overall")
ax.set_ylabel(" ")
plt.plot()

ax = soccer_sample.plot(kind="scatter", x=cols[8], y="Overall", color=colors[0], label=cols[8])
for i in range(9, 12):
    soccer_sample.plot(kind="scatter", x=cols[i], y="Overall", color=colors[i-8], label=cols[i], ax=ax)
ax.set_xlabel("Overall")
ax.set_ylabel(" ")
plt.plot()
# Out:
# []

# %% [markdown]
# Plot a correlation matrix between all of the numeric columns. A heatmap is an effective way to do so. Which pairs of features stand out as having exceptionally strong correlations, both positive and/or negative?

# %%
# answer goes here
corr = soccer_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
plt.plot()
# Out:
# []

# %% [markdown]
# Finally, create a pairplot using the numeric features in the dataset (i.e. scatterplots between pairs of features, rather than between Overall and the other features). Are the graphs visually consistent with what you would expect from the correlation heatmap?
#
# Note: there are too many numeric features to realistically generate a pairplot between all of them, so choose a subset. Choosing a fixed number of consecutive columns is fine (e.g. 10 through 20); you can also use the results of the correlation heatmap to guide your choices of columns. As with the previous exercise, using a sample of rows is recommended.

# %%
# answer goes here
soccer_sample = soccer_data.sample(n=20)
sns.set(style="ticks", color_codes=True)
sns.pairplot(soccer_sample, vars=cols[0:7])
plt.plot()
sns.pairplot(soccer_sample, vars=cols[7:14])
plt.plot()
sns.pairplot(soccer_sample, vars=cols[14:21])
plt.plot()
sns.pairplot(soccer_sample, vars=cols[21:28])
plt.plot()
# Out:
# []

# %% [markdown]
# For the Chicago traffic crash data, we will consider the "DAMAGE" column to be the response of interest, and the other columns to be potential features. Most of the features are categorical, so we can use contingency table to identify potentially strong associations between categorical features and our categorical response.
#
# Select one or two categorical variables that you suspect will have a strong relationship with the dollar amount of damages associated with a crash (we will choose TRAFFICWAY_TYPE), and print out the associated contigency table in two different forms:
#
# - Raw data counts
# - Percentage of total (i.e. the percentage of "OVER \$1500" for each level of a categorical variable)
#
# Are there any particular categories within a particular feature that are strongly associated with higher damages? Are there any caveats to keep in mind with some of the more extreme values in the contingency table?

# %%
crash_data['DAMAGE']
# Out:
# 0           OVER $1,500
# 1           OVER $1,500
# 2         $501 - $1,500
# 3         $501 - $1,500
# 4         $501 - $1,500
#               ...
# 372580    $501 - $1,500
# 372581      OVER $1,500
# 372582      OVER $1,500
# 372583      OVER $1,500
# 372584      OVER $1,500
# Name: DAMAGE, Length: 372585, dtype: object

# %%
crash_data['TRAFFICWAY_TYPE']
# Out:
# 0              DIVIDED - W/MEDIAN BARRIER
# 1         DIVIDED - W/MEDIAN (NOT RAISED)
# 2                                 ONE-WAY
# 3                             NOT DIVIDED
# 4                             PARKING LOT
#                        ...
# 372580                        NOT DIVIDED
# 372581                           FOUR WAY
# 372582                        NOT DIVIDED
# 372583                        NOT DIVIDED
# 372584                              OTHER
# Name: TRAFFICWAY_TYPE, Length: 372585, dtype: object

# %%
# answer goes here
count_tab = pd.crosstab(crash_data['DAMAGE'], crash_data['TRAFFICWAY_TYPE'])
count_tab
# Out:
# TRAFFICWAY_TYPE  ALLEY  CENTER TURN LANE  DIVIDED - W/MEDIAN (NOT RAISED)  \
# DAMAGE
# $500 OR LESS      1052               467                             9041
# $501 - $1,500     1737               821                            19850
# OVER $1,500       3104              2085                            40005
#
# TRAFFICWAY_TYPE  DIVIDED - W/MEDIAN BARRIER  DRIVEWAY  FIVE POINT, OR MORE  \
# DAMAGE
# $500 OR LESS                           2832       265                   17
# $501 - $1,500                          5591       418                   36
# OVER $1,500                           14468       616                  105
#
# TRAFFICWAY_TYPE  FOUR WAY  L-INTERSECTION  NOT DIVIDED  NOT REPORTED  ONE-WAY  \
# DAMAGE
# $500 OR LESS          696               1        21788             5     6829
# $501 - $1,500        1124               5        52784             7    15149
# OVER $1,500          4000              16        94782            39    27441
#
# TRAFFICWAY_TYPE  OTHER  PARKING LOT  RAMP  ROUNDABOUT  T-INTERSECTION  \
# DAMAGE
# $500 OR LESS      1611         4484   177           9             148
# $501 - $1,500     2949        10141   377           4             239
# OVER $1,500       6560        12322   659          26             869
#
# TRAFFICWAY_TYPE  TRAFFIC ROUTE  UNKNOWN  UNKNOWN INTERSECTION TYPE  \
# DAMAGE
# $500 OR LESS                16      565                         49
# $501 - $1,500               27     1231                         65
# OVER $1,500                 82     2331                        305
#
# TRAFFICWAY_TYPE  Y-INTERSECTION
# DAMAGE
# $500 OR LESS                 20
# $501 - $1,500                37
# OVER $1,500                 106

# %%
count_tab = pd.crosstab(crash_data['DAMAGE'], crash_data['TRAFFICWAY_TYPE'], normalize='columns')
count_tab = count_tab.select_dtypes(exclude=['object', 'datetime']) * 100
count_tab
# Out:
# TRAFFICWAY_TYPE      ALLEY  CENTER TURN LANE  DIVIDED - W/MEDIAN (NOT RAISED)  \
# DAMAGE
# $500 OR LESS     17.851688         13.845242                        13.122678
# $501 - $1,500    29.475649         24.340350                        28.811542
# OVER $1,500      52.672662         61.814409                        58.065780
#
# TRAFFICWAY_TYPE  DIVIDED - W/MEDIAN BARRIER   DRIVEWAY  FIVE POINT, OR MORE  \
# DAMAGE
# $500 OR LESS                      12.371674  20.400308            10.759494
# $501 - $1,500                     24.424446  32.178599            22.784810
# OVER $1,500                       63.203879  47.421093            66.455696
#
# TRAFFICWAY_TYPE   FOUR WAY  L-INTERSECTION  NOT DIVIDED  NOT REPORTED  \
# DAMAGE
# $500 OR LESS     11.958763        4.545455    12.865359      9.803922
# $501 - $1,500    19.312715       22.727273    31.167850     13.725490
# OVER $1,500      68.728522       72.727273    55.966791     76.470588
#
# TRAFFICWAY_TYPE    ONE-WAY      OTHER  PARKING LOT       RAMP  ROUNDABOUT  \
# DAMAGE
# $500 OR LESS     13.818572  14.487410    16.640071  14.591921   23.076923
# $501 - $1,500    30.654202  26.519784    37.633132  31.079967   10.256410
# OVER $1,500      55.527226  58.992806    45.726797  54.328112   66.666667
#
# TRAFFICWAY_TYPE  T-INTERSECTION  TRAFFIC ROUTE    UNKNOWN  \
# DAMAGE
# $500 OR LESS          11.783439           12.8  13.690332
# $501 - $1,500         19.028662           21.6  29.827962
# OVER $1,500           69.187898           65.6  56.481706
#
# TRAFFICWAY_TYPE  UNKNOWN INTERSECTION TYPE  Y-INTERSECTION
# DAMAGE
# $500 OR LESS                     11.694511       12.269939
# $501 - $1,500                    15.513126       22.699387
# OVER $1,500                      72.792363       65.030675
